# %% [markdown]
# # Homework 1
# ## Ahmet Buğra Taksuk - 2017402168

# %% [markdown]
# - Description

# %% [markdown]
# #### Reading the data

# %%
# Necessary libraries

import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
from scipy.spatial import distance
sns.set(rc={'figure.figsize':(8,6)})

# %%
df = pd.read_csv("CBF_TRAIN.txt", header = None,delim_whitespace = True)

# %% [markdown]
# #### Data Manipulation

# %%
class_ID = df[0]
df.index.name = "Instances"
df.drop(0, axis = 1, inplace = True)
df.insert(0, "Class_ID", class_ID)
df = df.T
df.head()
# Out:
# Instances        0         1         2         3         4         5   \
# Class_ID   1.000000  1.000000  1.000000  3.000000  2.000000  2.000000
# 1         -0.464276 -0.896972 -0.464696 -0.187190 -1.136017 -0.568709
# 2         -0.555048 -0.685686 -0.567739 -0.620808 -1.319195 -0.888118
# 3         -0.842843 -1.351382 -0.032023 -0.815661 -1.844624 -0.047977
# 4         -0.865895 -1.458667 -0.635046 -0.521398 -0.788692 -0.038036
#
# Instances        6         7         8         9         10        11  \
# Class_ID   1.000000  3.000000  2.000000  1.000000  2.000000  2.000000
# 1         -0.965839 -0.264302 -0.803716 -1.186422 -0.653308 -0.541876
# 2         -1.644583 -0.290925 -0.048161 -0.893197 -1.295185 -1.016107
# 3         -1.805935 -0.598567 -1.299278 -0.977737 -0.457384 -1.079902
# 4         -1.499658 -0.518863 -1.072280 -0.634109 -1.092036 -1.185665
#
# Instances        12        13        14        15        16        17  \
# Class_ID   1.000000  2.000000  2.000000  3.000000  2.000000  2.000000
# 1         -1.945327  0.045628 -0.413197 -1.659120 -0.725354 -1.457541
# 2         -1.449840 -1.129965 -0.400935 -1.001310 -0.837863 -0.668126
# 3         -1.488946 -0.520607 -0.482027  0.342287 -1.013462 -1.111360
# 4         -1.800484 -1.067185 -1.402971 -1.226010 -0.465730 -0.343084
#
# Instances        18        19        20        21        22        23  \
# Class_ID   1.000000  3.000000  2.000000  2.000000  1.000000  1.000000
# 1         -1.411368 -0.927105 -1.451680 -0.534452 -1.086040 -1.676169
# 2         -1.208220 -0.648515 -1.445272 -0.954354 -1.199305 -1.839363
# 3         -0.681907 -0.172875 -1.073598 -0.806711 -1.120579 -1.833647
# 4         -1.504585 -0.754255 -1.267250 -1.246832 -1.196342 -1.914525
#
# Instances        24        25        26        27        28        29
# Class_ID   3.000000  3.000000  2.000000  3.000000  3.000000  1.000000
# 1         -1.314889 -0.190921 -0.191813 -0.180493 -0.265888 -0.993315
# 2         -1.350861 -0.616051 -0.046090 -0.988931  0.013128 -0.869419
# 3         -0.574819 -0.598029 -1.365237 -0.301702 -1.028861 -0.345135
# 4         -0.713783 -0.625447 -0.907398 -0.475365 -1.090108 -0.996903

# %% [markdown]
# ## Task 1 ) Deciding on Lambda Parameter

# %%
import cvxpy as cp
import scipy as scipy
import cvxopt as cvxopt

beta = cp.Variable(128)
lmbda = 1
y = df[10][1:].values
objective = cp.Minimize(cp.sum_squares(y - beta) + lmbda*(cp.tv(beta)))

prob = cp.Problem(objective)

prob.solve()
plt.plot(beta.value, c = "r")
plt.plot(y, c = "b")
plt.show();

# %%
coef = np.ones((0, 128))
for i in range(0,30):
    for j in range(0,128,10):
        # test data for K =10
        test.append([j ,df[i].values[j]])
        coef[]
    lmbda = 1
    beta = cp.Variable(128)
    y = df[10][1:].values

        


    objective = cp.Minimize(cp.sum_squares(y - beta) + lmbda*(cp.tv(beta)))

    prob = cp.Problem(objective)
